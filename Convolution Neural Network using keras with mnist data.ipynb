# %%
import numpy as np
import matplotlib.pyplot as plt

from keras.datasets import mnist
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.layers import Input, Dense, Reshape, Dropout
from keras.optimizers import SGD, Adam

from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

# %%
lr = 0.01
wd = 0.01

batch_size = 128
num_epochs = 5

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test.shape
# Out:
# (10000, 28, 28)

# %%
def create_data():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.reshape(60000,-1)
    y_train = y_train.reshape(60000,-1)

    x_test = x_test.reshape(10000,-1)
    y_test = y_test.reshape(10000,-1)

    return x_train, y_train, x_test, y_test

# %%
def buildModel(x_train, y_train, x_test, y_test):

    input_img = Input(shape=(784,))
    
    reshape_1 = Reshape((28,28,1))(input_img)
    
    x= Conv2D(16,(3,3), activation = 'relu', padding ='same')(reshape_1)
    
    x = MaxPooling2D((2,2),padding='same')(x)
    
    x= Conv2D(8,(3,3), activation = 'relu', padding ='same')(x)
    
    x = MaxPooling2D((2,2),padding='same')(x)
    
    x= Conv2D(8,(3,3), activation = 'relu', padding ='same')(x)
    
    x = MaxPooling2D((2,2),padding='same')(x)

    reshape = Reshape((128,))(x)
    
    dense_4 = Dense(256, activation = 'relu')(reshape)

    output = Dense(1, activation='relu')(dense_4)

    model = Model(input_img, output)

    # optimizer
    sgd = SGD(lr=lr, decay=1e-3, momentum=0.9, nesterov=True, clipvalue=5.0)

    model.compile(loss='mean_squared_error', optimizer=sgd,metrics=['accuracy'])

    print (model.summary())
    
    model.fit(x_train, y_train, 
    nb_epoch=num_epochs, 
    batch_size=batch_size, 
    shuffle=True, 
    validation_data=(x_test, y_test))

    return model

# %%
def main():
    # getting the data
    x_train, y_train, x_test, y_test = create_data()

    model = buildModel(x_train, y_train, x_test, y_test)

    # decoded_imgs = autoencoder.predict(x_test)

    pass

# %%
if __name__ == '__main__':
    main()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 8)           584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 8)           0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 35,185
# Trainable params: 35,185
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:38: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 54s - loss: 781.9837 - val_loss: 28.1290
# Epoch 2/5
#  - ETA: 33s - loss: 28.1948
# Epoch 3/5
#  - ETA: 8s - loss: 28.1549
# Epoch 4/5
#  - ETA: 34s - loss: 28.2174
# Epoch 5/5
# 60000/60000 [==============================] - 47s - loss: 28.1853 - val_loss: 28.1290
